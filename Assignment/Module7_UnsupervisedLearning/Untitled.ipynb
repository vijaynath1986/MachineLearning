# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from PIL import Image

# %%
img = Image.open("dogs.jpeg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=272x185 at 0x1FE70772A60>

# %%
img_dat = np.array(img)

# %%
img_dat.shape
# Out:
# (185, 272, 3)

# %%
temp = img_dat
for i in np.arange(15):
    print(temp[0][i])
# Out:
# [240 240 240]
# [255 255 255]
# [255 255 255]
# [251 251 251]
# [255 255 255]
# [255 255 255]
# [253 253 253]
# [255 255 255]
# [255 255 255]
# [255 255 255]
# [255 255 255]
# [255 255 255]
# [255 255 255]
# [255 255 255]
# [255 255 255]

# %%
img_dat_reshapped = np.reshape(img_dat, (185, 272*3))

# %%
img_dat_reshapped.shape
# Out:
# (185, 816)

# %%
img_dat_reshapped[0][0]
# Out:
# 240

# %%
for i in np.arange(15):
    print(img_dat_reshapped[0][i])
# Out:
# 240
# 240
# 240
# 255
# 255
# 255
# 255
# 255
# 255
# 251
# 251
# 251
# 255
# 255
# 255

# %%
img_dat_reshapped[0].shape
# Out:
# (816,)

# %%
img_dat_reshapped[1].shape
# Out:
# (816,)

# %%
sns.scatterplot(img_dat_reshapped[150], img_dat_reshapped[151])
# Out:
# C:\Users\vijay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
from sklearn.cluster import KMeans

# %%
kmean_model = KMeans(n_clusters=3)

# %%
img_dat_reshapped.shape
# Out:
# (185, 816)
