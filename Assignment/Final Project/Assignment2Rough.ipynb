# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.datasets import make_blobs

# %%
X,y = make_blobs(n_samples = 500,n_features = 2,centers = 3,random_state = 23)
 
fig = plt.figure(0)
plt.grid(True)
plt.scatter(X[:,0],X[:,1])
plt.show()

# %%
# Out:
# array([[-4.21118368, -5.31371634,  3.71337033],
#        [-3.13567041, -5.20911351,  4.07925319],
#        [ 0.19066753,  7.97383453,  5.92090772],
#        ...,
#        [-5.92601745, -2.05048344,  2.03189491],
#        [-0.17730641,  7.8115827 ,  4.99414503],
#        [-5.39239167, -4.17463331, -0.47278228]])

# %%
df = pd.DataFrame(
    {
        "A": [1, 1, 2, 2,2],
        "B": [1, 2, 3, 4,5],
        "C": [0.362838, 0.227877, 1.267767, -0.562860, 0.5],
        "D": [4,5,6,7, 8],
    }
)

# %%
df
# Out:
#    A  B         C  D
# 0  1  1  0.362838  4
# 1  1  2  0.227877  5
# 2  2  3  1.267767  6
# 3  2  4 -0.562860  7
# 4  2  5  0.500000  8

# %%
df.groupby('A').agg(['min', 'max'])
# Out:
#     B             C             D
#   min max       min       max min max
# A
# 1   1   2  0.227877  0.362838   4   5
# 2   3   4 -0.562860  1.267767   6   7

# %%
df.groupby('A').agg(lambda x: sum(x) + 2)
# Out:
#    B         C   D
# A
# 1  5  2.590715  11
# 2  9  2.704907  15

# %%
df.groupby('A').agg({'D': "nunique"})
# Out:
#    D
# A
# 1  2
# 2  3
