# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random
from sklearn.cluster import DBSCAN
from sklearn.datasets import make_blobs
from sklearn.preprocessing import StandardScaler

# %%
dat = []
aligned = []

for each in range(30):
    dat.append(random.randint(-20,-5))
    aligned.append(0)
    
for each in range(160):
    dat.append(random.randint(-5,5))
    aligned.append(1)
    
for each in range(20):
    dat.append(random.randint(5,20))
    aligned.append(0)
    
random.shuffle(dat)
# Out:
#   File "C:\Users\vijay\AppData\Local\Temp/ipykernel_7532/607616231.py", line 16
#     £random.shuffle(dat)
#     ^
# SyntaxError: invalid character '£' (U+00A3)

# %%
plt.scatter(dat, range(len(dat)))

# %%
# #############################################################################
# Generate sample data
centers = [[0, 0], [-1.5, 0], [1.5, 0]]
X, labels_true = make_blobs(
    n_samples=750, centers=centers, cluster_std=0.4, random_state=2
)

X = StandardScaler().fit_transform(X)

# #############################################################################

# %%
sns.scatterplot(X[:,0], X[:,1], hue=labels_true, palette=['r', 'g', 'b'])
# Out:
# C:\Users\vijay\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:>

# %%
db = DBSCAN(eps=0.3, min_samples=10).fit(X)

# %%
core_samples_mask = np.zeros_like(db.labels_, dtype=bool)
core_samples_mask[db.core_sample_indices_] = True
labels = db.labels_

# %%
# Number of clusters in labels, ignoring noise if present.
n_clusters_ = len(set(labels)) - (1 if -1 in labels else 0)
n_noise_ = list(labels).count(-1)

# %%
n_clusters_
# Out:
# 1
